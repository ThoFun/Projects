# %%
import pandas as pd
import pgeocode

# %%
# Read the home price csv file
data_path = "../data/homegate_final_unprocessed.csv"

df = pd.read_csv(data_path, index_col=0)
df
# Out:
#                price              type  room_num floor area_m2  floors_num  \
# 0     CHF1,235,000.–         Apartment       2.5    GF  138 m2         4.0
# 1       CHF650,000.–         Apartment       4.5     1  121 m2         NaN
# 2     CHF1,062,900.–         Apartment       2.5     1   63 m2         NaN
# 3     CHF1,125,500.–        Attic flat       2.5     3   63 m2         NaN
# 4     CHF2,180,700.–         Apartment       3.5     2  125 m2         NaN
# ...              ...               ...       ...   ...     ...         ...
# 2181    CHF695,000.–  Bifamiliar house       4.5   NaN  144 m2         NaN
# 2182    CHF695,000.–  Bifamiliar house       4.5   NaN  144 m2         NaN
# 2183    CHF695,000.–         Row house       4.5   NaN  144 m2         NaN
# 2184    CHF695,000.–  Bifamiliar house       4.5   NaN  144 m2         NaN
# 2185    CHF695,000.–  Bifamiliar house       4.5   NaN  144 m2         NaN
#
#       year_built  last_refurbishment                          address
# 0         2015.0              2018.0             8914 Aeugst am Albis
# 1         1987.0              2021.0  Via Vecchio Canale 2, 6982 Agno
# 2            NaN                 NaN       Via Campione, 6816 Bissone
# 3            NaN                 NaN       Via Campione, 6816 Bissone
# 4            NaN                 NaN       Via Campione, 6816 Bissone
# ...          ...                 ...                              ...
# 2181      2022.0                 NaN              1994 Aproz (Nendaz)
# 2182      2022.0                 NaN              1994 Aproz (Nendaz)
# 2183      2022.0                 NaN              1994 Aproz (Nendaz)
# 2184      2022.0                 NaN              1994 Aproz (Nendaz)
# 2185      2022.0                 NaN              1994 Aproz (Nendaz)
#
# [2186 rows x 9 columns]

# %% [markdown]
# ---
# The first method we will use on our newly created dataframe is `.info()`. Here we can get a first overview of the types of data we have, and if we have missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2186 entries, 0 to 2185
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               2186 non-null   object
#  1   type                2186 non-null   object
#  2   room_num            2072 non-null   float64
#  3   floor               928 non-null    object
#  4   area_m2             2021 non-null   object
#  5   floors_num          713 non-null    float64
#  6   year_built          1652 non-null   float64
#  7   last_refurbishment  489 non-null    float64
#  8   address             2186 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 170.8+ KB

# %% [markdown]
# ---
# The price column is formatted with alphanumeric values. In order to properly do data exploration, we need to treat this column as an integer (number), so let's clean this entries using a Regular Expression (regex) so it only keeps the digits

# %%
df["price"]
# Out:
# 0       CHF1,235,000.–
# 1         CHF650,000.–
# 2       CHF1,062,900.–
# 3       CHF1,125,500.–
# 4       CHF2,180,700.–
#              ...
# 2181      CHF695,000.–
# 2182      CHF695,000.–
# 2183      CHF695,000.–
# 2184      CHF695,000.–
# 2185      CHF695,000.–
# Name: price, Length: 2186, dtype: object

# %%
df["price"].sample(n=10).unique()
# Out:
# array(['CHF340,000.–', 'CHF1,040,000.–', 'CHF745,000.–', 'CHF1,890,000.–',
#        'CHF525,000.–', 'CHF2,010,000.–', 'CHF680,000.–', 'CHF570,000.–',
#        'CHF672,000.–', 'CHF4,590,000.–'], dtype=object)

# %%
df['price'] = df['price'].str.replace('[^0-9]', '', regex=True)
df.head()
# Out:
#      price        type  room_num floor area_m2  floors_num  year_built  \
# 0  1235000   Apartment       2.5    GF  138 m2         4.0      2015.0
# 1   650000   Apartment       4.5     1  121 m2         NaN      1987.0
# 2  1062900   Apartment       2.5     1   63 m2         NaN         NaN
# 3  1125500  Attic flat       2.5     3   63 m2         NaN         NaN
# 4  2180700   Apartment       3.5     2  125 m2         NaN         NaN
#
#    last_refurbishment                          address
# 0              2018.0             8914 Aeugst am Albis
# 1              2021.0  Via Vecchio Canale 2, 6982 Agno
# 2                 NaN       Via Campione, 6816 Bissone
# 3                 NaN       Via Campione, 6816 Bissone
# 4                 NaN       Via Campione, 6816 Bissone

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2186 entries, 0 to 2185
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               2186 non-null   object
#  1   type                2186 non-null   object
#  2   room_num            2072 non-null   float64
#  3   floor               928 non-null    object
#  4   area_m2             2021 non-null   object
#  5   floors_num          713 non-null    float64
#  6   year_built          1652 non-null   float64
#  7   last_refurbishment  489 non-null    float64
#  8   address             2186 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 170.8+ KB

# %% [markdown]
# ---
# Even though we stripped the values of non-numerical characters, we still need to convert the data type so it can be interpreted as an integer. This way we can later take advantage of this for plotting and applying methods if needed.

# %%
df['price'] = df['price'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2186 entries, 0 to 2185
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               2186 non-null   int32
#  1   type                2186 non-null   object
#  2   room_num            2072 non-null   float64
#  3   floor               928 non-null    object
#  4   area_m2             2021 non-null   object
#  5   floors_num          713 non-null    float64
#  6   year_built          1652 non-null   float64
#  7   last_refurbishment  489 non-null    float64
#  8   address             2186 non-null   object
# dtypes: float64(4), int32(1), object(4)
# memory usage: 162.2+ KB

# %%
df['area_m2'] = df['area_m2'].str.split(' ').str[0]
df['area_m2'] = df['area_m2'].astype(float)
df.head(3)
# Out:
#      price       type  room_num floor  area_m2  floors_num  year_built  \
# 0  1235000  Apartment       2.5    GF    138.0         4.0      2015.0
# 1   650000  Apartment       4.5     1    121.0         NaN      1987.0
# 2  1062900  Apartment       2.5     1     63.0         NaN         NaN
#
#    last_refurbishment                          address
# 0              2018.0             8914 Aeugst am Albis
# 1              2021.0  Via Vecchio Canale 2, 6982 Agno
# 2                 NaN       Via Campione, 6816 Bissone

# %%
print(f"Missing values in 'floors_num': {df['floors_num'].isna().sum()}")
# Out:
# Missing values in 'floors_num': 1473

# %%
# Most missing values in 'floors_num' are Ground Floor properties
df['floors_num'] = df['floors_num'].fillna(1).astype(int)
df.head()
# Out:
#      price        type  room_num floor  area_m2  floors_num  year_built  \
# 0  1235000   Apartment       2.5    GF    138.0           4      2015.0
# 1   650000   Apartment       4.5     1    121.0           1      1987.0
# 2  1062900   Apartment       2.5     1     63.0           1         NaN
# 3  1125500  Attic flat       2.5     3     63.0           1         NaN
# 4  2180700   Apartment       3.5     2    125.0           1         NaN
#
#    last_refurbishment                          address
# 0              2018.0             8914 Aeugst am Albis
# 1              2021.0  Via Vecchio Canale 2, 6982 Agno
# 2                 NaN       Via Campione, 6816 Bissone
# 3                 NaN       Via Campione, 6816 Bissone
# 4                 NaN       Via Campione, 6816 Bissone

# %%
print(f"Missing values in 'floor': {df['floor'].isna().sum()}")
# Out:
# Missing values in 'floor': 1258

# %%
# Filling the missing values of the 'floor' column with "GF"
df['floor'] = df['floor'].fillna("GF")
df.tail()
# Out:
#        price              type  room_num floor  area_m2  floors_num  \
# 2181  695000  Bifamiliar house       4.5    GF    144.0           1
# 2182  695000  Bifamiliar house       4.5    GF    144.0           1
# 2183  695000         Row house       4.5    GF    144.0           1
# 2184  695000  Bifamiliar house       4.5    GF    144.0           1
# 2185  695000  Bifamiliar house       4.5    GF    144.0           1
#
#       year_built  last_refurbishment              address
# 2181      2022.0                 NaN  1994 Aproz (Nendaz)
# 2182      2022.0                 NaN  1994 Aproz (Nendaz)
# 2183      2022.0                 NaN  1994 Aproz (Nendaz)
# 2184      2022.0                 NaN  1994 Aproz (Nendaz)
# 2185      2022.0                 NaN  1994 Aproz (Nendaz)

# %%
print(f"Missing values in 'last_refurbishment': {df['last_refurbishment'].isna().sum()}")
# Out:
# Missing values in 'last_refurbishment': 1697

# %%
df["year_built"]
# Out:
# 0       2015.0
# 1       1987.0
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 2181    2022.0
# 2182    2022.0
# 2183    2022.0
# 2184    2022.0
# 2185    2022.0
# Name: year_built, Length: 2186, dtype: float64

# %%
# Filling the missing values in the column 'last_refurbishment' with the values from the column 'year_built'
df['last_refurbishment'] = df['last_refurbishment'].fillna(df['year_built'])

df
# Out:
#         price              type  room_num floor  area_m2  floors_num  \
# 0     1235000         Apartment       2.5    GF    138.0           4
# 1      650000         Apartment       4.5     1    121.0           1
# 2     1062900         Apartment       2.5     1     63.0           1
# 3     1125500        Attic flat       2.5     3     63.0           1
# 4     2180700         Apartment       3.5     2    125.0           1
# ...       ...               ...       ...   ...      ...         ...
# 2181   695000  Bifamiliar house       4.5    GF    144.0           1
# 2182   695000  Bifamiliar house       4.5    GF    144.0           1
# 2183   695000         Row house       4.5    GF    144.0           1
# 2184   695000  Bifamiliar house       4.5    GF    144.0           1
# 2185   695000  Bifamiliar house       4.5    GF    144.0           1
#
#       year_built  last_refurbishment                          address
# 0         2015.0              2018.0             8914 Aeugst am Albis
# 1         1987.0              2021.0  Via Vecchio Canale 2, 6982 Agno
# 2            NaN                 NaN       Via Campione, 6816 Bissone
# 3            NaN                 NaN       Via Campione, 6816 Bissone
# 4            NaN                 NaN       Via Campione, 6816 Bissone
# ...          ...                 ...                              ...
# 2181      2022.0              2022.0              1994 Aproz (Nendaz)
# 2182      2022.0              2022.0              1994 Aproz (Nendaz)
# 2183      2022.0              2022.0              1994 Aproz (Nendaz)
# 2184      2022.0              2022.0              1994 Aproz (Nendaz)
# 2185      2022.0              2022.0              1994 Aproz (Nendaz)
#
# [2186 rows x 9 columns]

# %%
# Getting the price per square meter
df = df[df["area_m2"].notna()].copy()
df["price_sqm"] = df['price'] / df['area_m2']
df["price_sqm"] = df["price_sqm"].astype(int)
print(df.shape)
df.head()
# Out:
# (2021, 10)
#      price        type  room_num floor  area_m2  floors_num  year_built  \
# 0  1235000   Apartment       2.5    GF    138.0           4      2015.0
# 1   650000   Apartment       4.5     1    121.0           1      1987.0
# 2  1062900   Apartment       2.5     1     63.0           1         NaN
# 3  1125500  Attic flat       2.5     3     63.0           1         NaN
# 4  2180700   Apartment       3.5     2    125.0           1         NaN
#
#    last_refurbishment                          address  price_sqm
# 0              2018.0             8914 Aeugst am Albis       8949
# 1              2021.0  Via Vecchio Canale 2, 6982 Agno       5371
# 2                 NaN       Via Campione, 6816 Bissone      16871
# 3                 NaN       Via Campione, 6816 Bissone      17865
# 4                 NaN       Via Campione, 6816 Bissone      17445

# %%
for address in df['address'].sample(n=20).unique():
  print(address)
# Out:
# Via Nosetto, 6987 Caslano
# St. Johannserstrasse, 5312 Döttingen
# 6612 Ascona
# 2942 Alle
# Nordstrasse 1, 8620 Wetzikon ZH
# Seestrasse 43, 6354 Vitznau
# 6781 Bedretto
# Kohlplatzweg 7, 4310 Rheinfelden
# 6883 Novazzano
# 8050 Zürich
# 6814 Cadempino
# 6596 Gordola
# Via S. Gottardo, 6900 Lugano
# rue auguste cuenin 10, 2900 Porrentruy
# 8461 Kleinandelfingen
# 6748 Anzonico
# Via poncione e Vespero 34, 6780 Airolo
# Via Trevano, 6900 Lugano
# Pulvermühleweg 6, 6010 Kriens
# 1950 Sion

# %%
def extract_zip_city(address):
    if ',' in address:
        zip_and_city = address.split(', ')[1]
        zip_code = zip_and_city.split(' ')[0]
        city = zip_and_city.split(' ')[1]
    else:
        zip_and_city = address
        zip_code = zip_and_city.split(' ')[0]
        city = zip_and_city.split(' ')[1]
    return pd.Series([zip_code, city])

df[['zip_code', 'city']] = df['address'].apply(extract_zip_city)
df
# Out:
#         price              type  room_num floor  area_m2  floors_num  \
# 0     1235000         Apartment       2.5    GF    138.0           4
# 1      650000         Apartment       4.5     1    121.0           1
# 2     1062900         Apartment       2.5     1     63.0           1
# 3     1125500        Attic flat       2.5     3     63.0           1
# 4     2180700         Apartment       3.5     2    125.0           1
# ...       ...               ...       ...   ...      ...         ...
# 2181   695000  Bifamiliar house       4.5    GF    144.0           1
# 2182   695000  Bifamiliar house       4.5    GF    144.0           1
# 2183   695000         Row house       4.5    GF    144.0           1
# 2184   695000  Bifamiliar house       4.5    GF    144.0           1
# 2185   695000  Bifamiliar house       4.5    GF    144.0           1
#
#       year_built  last_refurbishment                          address  \
# 0         2015.0              2018.0             8914 Aeugst am Albis
# 1         1987.0              2021.0  Via Vecchio Canale 2, 6982 Agno
# 2            NaN                 NaN       Via Campione, 6816 Bissone
# 3            NaN                 NaN       Via Campione, 6816 Bissone
# 4            NaN                 NaN       Via Campione, 6816 Bissone
# ...          ...                 ...                              ...
# 2181      2022.0              2022.0              1994 Aproz (Nendaz)
# 2182      2022.0              2022.0              1994 Aproz (Nendaz)
# 2183      2022.0              2022.0              1994 Aproz (Nendaz)
# 2184      2022.0              2022.0              1994 Aproz (Nendaz)
# 2185      2022.0              2022.0              1994 Aproz (Nendaz)
#
#       price_sqm zip_code     city
# 0          8949     8914   Aeugst
# 1          5371     6982     Agno
# 2         16871     6816  Bissone
# 3         17865     6816  Bissone
# 4         17445     6816  Bissone
# ...         ...      ...      ...
# 2181       4826     1994    Aproz
# 2182       4826     1994    Aproz
# 2183       4826     1994    Aproz
# 2184       4826     1994    Aproz
# 2185       4826     1994    Aproz
#
# [2021 rows x 12 columns]

# %%
pgeocode_nomi = pgeocode.Nominatim('ch')
pgeocode_nomi.query_postal_code("8600")
# Out:
# postal_code                         8600
# country_code                          CH
# place_name        Dübendorf, Dübendorf 1
# state_name                 Kanton Zürich
# state_code                            ZH
# county_name                 Bezirk Uster
# county_code                          109
# community_name                 Dübendorf
# community_code                       191
# latitude                         47.3921
# longitude                         8.6187
# accuracy                             4.0
# Name: 0, dtype: object

# %%
def add_canton(zip_code):
    zip_info = pgeocode_nomi.query_postal_code(zip_code)
    return zip_info["state_name"]

df["canton"] = df["zip_code"].apply(add_canton)
df.head(3)
# Out:
#      price       type  room_num floor  area_m2  floors_num  year_built  \
# 0  1235000  Apartment       2.5    GF    138.0           4      2015.0
# 1   650000  Apartment       4.5     1    121.0           1      1987.0
# 2  1062900  Apartment       2.5     1     63.0           1         NaN
#
#    last_refurbishment                          address  price_sqm zip_code  \
# 0              2018.0             8914 Aeugst am Albis       8949     8914
# 1              2021.0  Via Vecchio Canale 2, 6982 Agno       5371     6982
# 2                 NaN       Via Campione, 6816 Bissone      16871     6816
#
#       city         canton
# 0   Aeugst  Kanton Zürich
# 1     Agno         Ticino
# 2  Bissone         Ticino

# %%
def add_coordinates(zip_code): 
    zip_info = pgeocode_nomi.query_postal_code(zip_code)
    # Assign two variables called 'latitude' and 'longitude' with the corresponding keys from the 'zip_info' data
    latitude = zip_info["latitude"]
    longitude = zip_info["longitude"]
    return pd.Series([latitude, longitude])

df[["lat", "lon"]] = df["zip_code"].apply(add_coordinates)
df.head(3)
# Out:
#      price       type  room_num floor  area_m2  floors_num  year_built  \
# 0  1235000  Apartment       2.5    GF    138.0           4      2015.0
# 1   650000  Apartment       4.5     1    121.0           1      1987.0
# 2  1062900  Apartment       2.5     1     63.0           1         NaN
#
#    last_refurbishment                          address  price_sqm zip_code  \
# 0              2018.0             8914 Aeugst am Albis       8949     8914
# 1              2021.0  Via Vecchio Canale 2, 6982 Agno       5371     6982
# 2                 NaN       Via Campione, 6816 Bissone      16871     6816
#
#       city         canton       lat      lon
# 0   Aeugst  Kanton Zürich  47.27515  8.48965
# 1     Agno         Ticino  46.00050  8.90280
# 2  Bissone         Ticino  45.95100  8.96550

# %%
df = df.drop('address', axis=1)

# %%
df
# Out:
#         price              type  room_num floor  area_m2  floors_num  \
# 0     1235000         Apartment       2.5    GF    138.0           4
# 1      650000         Apartment       4.5     1    121.0           1
# 2     1062900         Apartment       2.5     1     63.0           1
# 3     1125500        Attic flat       2.5     3     63.0           1
# 4     2180700         Apartment       3.5     2    125.0           1
# ...       ...               ...       ...   ...      ...         ...
# 2181   695000  Bifamiliar house       4.5    GF    144.0           1
# 2182   695000  Bifamiliar house       4.5    GF    144.0           1
# 2183   695000         Row house       4.5    GF    144.0           1
# 2184   695000  Bifamiliar house       4.5    GF    144.0           1
# 2185   695000  Bifamiliar house       4.5    GF    144.0           1
#
#       year_built  last_refurbishment  price_sqm zip_code     city  \
# 0         2015.0              2018.0       8949     8914   Aeugst
# 1         1987.0              2021.0       5371     6982     Agno
# 2            NaN                 NaN      16871     6816  Bissone
# 3            NaN                 NaN      17865     6816  Bissone
# 4            NaN                 NaN      17445     6816  Bissone
# ...          ...                 ...        ...      ...      ...
# 2181      2022.0              2022.0       4826     1994    Aproz
# 2182      2022.0              2022.0       4826     1994    Aproz
# 2183      2022.0              2022.0       4826     1994    Aproz
# 2184      2022.0              2022.0       4826     1994    Aproz
# 2185      2022.0              2022.0       4826     1994    Aproz
#
#                 canton       lat      lon
# 0        Kanton Zürich  47.27515  8.48965
# 1               Ticino  46.00050  8.90280
# 2               Ticino  45.95100  8.96550
# 3               Ticino  45.95100  8.96550
# 4               Ticino  45.95100  8.96550
# ...                ...       ...      ...
# 2181  Canton du Valais  46.20380  7.30700
# 2182  Canton du Valais  46.20380  7.30700
# 2183  Canton du Valais  46.20380  7.30700
# 2184  Canton du Valais  46.20380  7.30700
# 2185  Canton du Valais  46.20380  7.30700
#
# [2021 rows x 14 columns]

# %%
df = df[df['price']< 5000000].reset_index(drop=True)
#df = df[~df["year_built"].isna()]
df.drop(['lat', 'lon', 'price_sqm'], axis=1, inplace=True, errors='ignore')
df
# Out:
#         price              type  room_num floor  area_m2  floors_num  \
# 0     1235000         Apartment       2.5    GF    138.0           4
# 1      650000         Apartment       4.5     1    121.0           1
# 2     1062900         Apartment       2.5     1     63.0           1
# 3     1125500        Attic flat       2.5     3     63.0           1
# 4     2180700         Apartment       3.5     2    125.0           1
# ...       ...               ...       ...   ...      ...         ...
# 1928   695000  Bifamiliar house       4.5    GF    144.0           1
# 1929   695000  Bifamiliar house       4.5    GF    144.0           1
# 1930   695000         Row house       4.5    GF    144.0           1
# 1931   695000  Bifamiliar house       4.5    GF    144.0           1
# 1932   695000  Bifamiliar house       4.5    GF    144.0           1
#
#       year_built  last_refurbishment zip_code     city            canton
# 0         2015.0              2018.0     8914   Aeugst     Kanton Zürich
# 1         1987.0              2021.0     6982     Agno            Ticino
# 2            NaN                 NaN     6816  Bissone            Ticino
# 3            NaN                 NaN     6816  Bissone            Ticino
# 4            NaN                 NaN     6816  Bissone            Ticino
# ...          ...                 ...      ...      ...               ...
# 1928      2022.0              2022.0     1994    Aproz  Canton du Valais
# 1929      2022.0              2022.0     1994    Aproz  Canton du Valais
# 1930      2022.0              2022.0     1994    Aproz  Canton du Valais
# 1931      2022.0              2022.0     1994    Aproz  Canton du Valais
# 1932      2022.0              2022.0     1994    Aproz  Canton du Valais
#
# [1933 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder
import joblib
from interpret import show
from interpret.glassbox import ExplainableBoostingRegressor
import time
from tensorflow.python.keras.losses import mean_absolute_error

# %%
# TensorBoard setup
log_dir = "logs/fit/" + time.strftime("%Y-%m-%d_%H-%M-%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Preprocess data
X = df.drop(columns=['price'])
y = df['price']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define preprocessing for numeric features (standard scaling and imputation)
numeric_features = ['room_num', 'area_m2', 'floors_num', 'year_built', 'last_refurbishment']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# Define preprocessing for categorical features (one-hot encoding)
categorical_features = ['type', 'floor', 'zip_code', 'city', 'canton']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Combine preprocessing for numeric and categorical features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Fit and transform the data
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Convert sparse matrix to dense matrix if needed
if hasattr(X_train_transformed, 'toarray'):
    X_train_transformed = X_train_transformed.toarray()
    X_test_transformed = X_test_transformed.toarray()

# Manually create feature names
feature_names = numeric_features.copy()
for cat_feature in categorical_features:
    n_unique_values = len(df[cat_feature].unique())
    feature_names.extend([f"{cat_feature}_{i}" for i in range(n_unique_values)])

print(f"X_train_transformed shape: {X_train_transformed.shape}")

# Build a neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=X_train_transformed.shape[1]),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# Train the neural network model and log the metrics
start_time = time.time()
history = model.fit(X_train_transformed, y_train, epochs=100, validation_split=0.2, callbacks=[tensorboard_callback])
end_time = time.time()
training_time = end_time - start_time
print(f"Time taken to train neural network model: {training_time} seconds")

# Evaluate the model on test data
y_pred = model.predict(X_test_transformed)
test_mae = mean_absolute_error(y_test, y_pred)

# Save the trained model and preprocessor
model.save('../web/rf_model.h5')
joblib.dump(preprocessor, '../web/preprocessor.joblib')

# Interpret ML feature engineering
ebm = ExplainableBoostingRegressor(random_state=42)

# Measure the time taken to fit the EBM model
start_time = time.time()
ebm.fit(X_train_transformed, y_train)
end_time = time.time()
ebm_training_time = end_time - start_time
print(f"Time taken to fit EBM model: {ebm_training_time} seconds")

# Assign the extracted feature names to the EBM model
ebm.feature_names = feature_names

# Measure the time taken to get the global explanation
start_time = time.time()
ebm_global = ebm.explain_global(name='EBM')
end_time = time.time()
global_explanation_time = end_time - start_time
print(f"Time taken to generate global explanation: {global_explanation_time} seconds")

# Show the global explanation
show(ebm_global)
# Out:
# X_train_transformed shape: (1353, 1106)
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1297441.7500 - mean_absolute_error: 1297441.7500 - val_loss: 1263358.2500 - val_mean_absolute_error: 1263358.2500
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1266639.3750 - mean_absolute_error: 1266639.3750 - val_loss: 1256022.6250 - val_mean_absolute_error: 1256022.6250
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1262221.3750 - mean_absolute_error: 1262221.3750 - val_loss: 1124633.6250 - val_mean_absolute_error: 1124633.5000
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1038081.4375 - mean_absolute_error: 1038081.4375 - val_loss: 665691.6875 - val_mean_absolute_error: 665691.6875
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 682762.3750 - mean_absolute_error: 682762.3750 - val_loss: 551463.6875 - val_mean_absolute_error: 551463.6875
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 554552.1250 - mean_absolute_error: 554552.1250 - val_loss: 487551.9375 - val_mean_absolute_error: 487551.9375
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 485263.9062 - mean_absolute_error: 485263.9062 - val_loss: 440040.7500 - val_mean_absolute_error: 440040.7500
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 402340.6250 - mean_absolute_error: 402340.6250 - val_loss: 406540.7500 - val_mean_absolute_error: 406540.7500
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 390585.8438 - mean_absolute_error: 390585.8438 - val_loss: 385043.4375 - val_mean_absolute_error: 385043.4375
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 341714.0625 - mean_absolute_error: 341714.0625 - val_loss: 371636.1875 - val_mean_absolute_error: 371636.1875
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 315008.4375 - mean_absolute_error: 315008.4375 - val_loss: 363667.8750 - val_mean_absolute_error: 363667.8750
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 305083.8750 - mean_absolute_error: 305083.8750 - val_loss: 354537.7812 - val_mean_absolute_error: 354537.7812
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 261910.1094 - mean_absolute_error: 261910.1094 - val_loss: 350960.4062 - val_mean_absolute_error: 350960.4062
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 271137.1250 - mean_absolute_error: 271137.1250 - val_loss: 348752.7812 - val_mean_absolute_error: 348752.7812
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 250297.8125 - mean_absolute_error: 250297.8125 - val_loss: 344572.0938 - val_mean_absolute_error: 344572.0938
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 271863.0938 - mean_absolute_error: 271863.0938 - val_loss: 345197.0000 - val_mean_absolute_error: 345197.0000
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 253943.0312 - mean_absolute_error: 253943.0312 - val_loss: 340569.1250 - val_mean_absolute_error: 340569.1250
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 235978.8125 - mean_absolute_error: 235978.8125 - val_loss: 341040.2812 - val_mean_absolute_error: 341040.2812
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 238904.6875 - mean_absolute_error: 238904.6875 - val_loss: 337694.5938 - val_mean_absolute_error: 337694.5938
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 233922.7812 - mean_absolute_error: 233922.7812 - val_loss: 337899.2812 - val_mean_absolute_error: 337899.2812
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 217933.6250 - mean_absolute_error: 217933.6250 - val_loss: 338734.9062 - val_mean_absolute_error: 338734.9062
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 222062.6094 - mean_absolute_error: 222062.6094 - val_loss: 339865.7812 - val_mean_absolute_error: 339865.7812
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 219692.6875 - mean_absolute_error: 219692.6875 - val_loss: 341068.9688 - val_mean_absolute_error: 341068.9688
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 217249.7344 - mean_absolute_error: 217249.7344 - val_loss: 336678.6250 - val_mean_absolute_error: 336678.6250
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 201527.2656 - mean_absolute_error: 201527.2656 - val_loss: 337107.8438 - val_mean_absolute_error: 337107.8438
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 208133.8281 - mean_absolute_error: 208133.8281 - val_loss: 336420.2812 - val_mean_absolute_error: 336420.2812
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 205669.1250 - mean_absolute_error: 205669.1250 - val_loss: 339277.8750 - val_mean_absolute_error: 339277.8750
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 209731.5938 - mean_absolute_error: 209731.5938 - val_loss: 337779.1250 - val_mean_absolute_error: 337779.1250
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 205216.4062 - mean_absolute_error: 205216.4062 - val_loss: 340448.6562 - val_mean_absolute_error: 340448.6562
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 203278.8281 - mean_absolute_error: 203278.8281 - val_loss: 340334.8125 - val_mean_absolute_error: 340334.8125
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 198137.8594 - mean_absolute_error: 198137.8594 - val_loss: 342594.9688 - val_mean_absolute_error: 342594.9688
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 191013.4844 - mean_absolute_error: 191013.4844 - val_loss: 344895.9062 - val_mean_absolute_error: 344895.9062
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 200561.3750 - mean_absolute_error: 200561.3750 - val_loss: 343520.2812 - val_mean_absolute_error: 343520.2812
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 195437.8594 - mean_absolute_error: 195437.8594 - val_loss: 343252.5938 - val_mean_absolute_error: 343252.5938
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 190698.3125 - mean_absolute_error: 190698.3125 - val_loss: 346251.8750 - val_mean_absolute_error: 346251.8750
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 176364.9219 - mean_absolute_error: 176364.9219 - val_loss: 344740.1250 - val_mean_absolute_error: 344740.1250
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 184616.1094 - mean_absolute_error: 184616.1094 - val_loss: 346314.0938 - val_mean_absolute_error: 346314.0938
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 190880.8125 - mean_absolute_error: 190880.8125 - val_loss: 346585.3125 - val_mean_absolute_error: 346585.3125
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 181989.8750 - mean_absolute_error: 181989.8750 - val_loss: 352355.2500 - val_mean_absolute_error: 352355.2500
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 168223.5156 - mean_absolute_error: 168223.5156 - val_loss: 350711.4062 - val_mean_absolute_error: 350711.4062
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 168929.8594 - mean_absolute_error: 168929.8594 - val_loss: 347749.3438 - val_mean_absolute_error: 347749.3438
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 178408.4062 - mean_absolute_error: 178408.4062 - val_loss: 347634.0625 - val_mean_absolute_error: 347634.0625
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 170387.0469 - mean_absolute_error: 170387.0469 - val_loss: 350546.4375 - val_mean_absolute_error: 350546.4375
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 181245.7344 - mean_absolute_error: 181245.7344 - val_loss: 346925.0938 - val_mean_absolute_error: 346925.0938
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 177016.5781 - mean_absolute_error: 177016.5781 - val_loss: 350668.5312 - val_mean_absolute_error: 350668.5312
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 178457.8750 - mean_absolute_error: 178457.8750 - val_loss: 352057.8750 - val_mean_absolute_error: 352057.8750
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 175642.9219 - mean_absolute_error: 175642.9219 - val_loss: 351122.0938 - val_mean_absolute_error: 351122.0938
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 170549.1719 - mean_absolute_error: 170549.1719 - val_loss: 352252.2812 - val_mean_absolute_error: 352252.2812
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 168493.2188 - mean_absolute_error: 168493.2188 - val_loss: 356649.8438 - val_mean_absolute_error: 356649.8438
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 159764.0156 - mean_absolute_error: 159764.0156 - val_loss: 357050.5938 - val_mean_absolute_error: 357050.5938
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 157665.2031 - mean_absolute_error: 157665.2031 - val_loss: 355995.3750 - val_mean_absolute_error: 355995.3750
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 170511.8438 - mean_absolute_error: 170511.8438 - val_loss: 354949.4062 - val_mean_absolute_error: 354949.4062
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 165354.9219 - mean_absolute_error: 165354.9219 - val_loss: 357959.8750 - val_mean_absolute_error: 357959.8750
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 161130.1719 - mean_absolute_error: 161130.1719 - val_loss: 357561.8125 - val_mean_absolute_error: 357561.8125
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 173911.1250 - mean_absolute_error: 173911.1250 - val_loss: 359214.6562 - val_mean_absolute_error: 359214.6562
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 177337.5000 - mean_absolute_error: 177337.5000 - val_loss: 360045.0625 - val_mean_absolute_error: 360045.0625
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 158123.7812 - mean_absolute_error: 158123.7812 - val_loss: 359414.2188 - val_mean_absolute_error: 359414.2188
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 159820.7812 - mean_absolute_error: 159820.7812 - val_loss: 359068.5625 - val_mean_absolute_error: 359068.5625
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 146171.9531 - mean_absolute_error: 146171.9531 - val_loss: 359487.3125 - val_mean_absolute_error: 359487.3125
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 165940.3594 - mean_absolute_error: 165940.3594 - val_loss: 357330.9062 - val_mean_absolute_error: 357330.9062
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 142289.7969 - mean_absolute_error: 142289.7969 - val_loss: 359505.1562 - val_mean_absolute_error: 359505.1562
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 166269.7812 - mean_absolute_error: 166269.7812 - val_loss: 362099.5625 - val_mean_absolute_error: 362099.5625
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 161407.3281 - mean_absolute_error: 161407.3281 - val_loss: 362231.2812 - val_mean_absolute_error: 362231.2812
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 138521.1719 - mean_absolute_error: 138521.1719 - val_loss: 359274.7812 - val_mean_absolute_error: 359274.7812
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 158404.7812 - mean_absolute_error: 158404.7812 - val_loss: 363612.9688 - val_mean_absolute_error: 363612.9688
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 158060.7344 - mean_absolute_error: 158060.7344 - val_loss: 359456.2188 - val_mean_absolute_error: 359456.2188
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 162752.5469 - mean_absolute_error: 162752.5469 - val_loss: 361352.0312 - val_mean_absolute_error: 361352.0312
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 173159.0156 - mean_absolute_error: 173159.0156 - val_loss: 364811.6250 - val_mean_absolute_error: 364811.6250
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 155063.5938 - mean_absolute_error: 155063.5938 - val_loss: 362783.9375 - val_mean_absolute_error: 362783.9375
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 171933.3125 - mean_absolute_error: 171933.3125 - val_loss: 363736.1875 - val_mean_absolute_error: 363736.1875
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 162897.2812 - mean_absolute_error: 162897.2812 - val_loss: 365529.3438 - val_mean_absolute_error: 365529.3438
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 158322.9531 - mean_absolute_error: 158322.9531 - val_loss: 366862.5938 - val_mean_absolute_error: 366862.5938
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 158837.1094 - mean_absolute_error: 158837.1094 - val_loss: 364964.8438 - val_mean_absolute_error: 364964.8438
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 164329.1406 - mean_absolute_error: 164329.1406 - val_loss: 362582.8750 - val_mean_absolute_error: 362582.8750
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 167208.9531 - mean_absolute_error: 167208.9531 - val_loss: 362816.7188 - val_mean_absolute_error: 362816.7188
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 151600.8438 - mean_absolute_error: 151600.8438 - val_loss: 362548.6875 - val_mean_absolute_error: 362548.6875
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 169534.1094 - mean_absolute_error: 169534.1094 - val_loss: 364185.3750 - val_mean_absolute_error: 364185.3750
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 159947.9688 - mean_absolute_error: 159947.9688 - val_loss: 365048.7188 - val_mean_absolute_error: 365048.7188
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 148682.4844 - mean_absolute_error: 148682.4844 - val_loss: 362638.2500 - val_mean_absolute_error: 362638.2500
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 155556.8438 - mean_absolute_error: 155556.8438 - val_loss: 366910.7188 - val_mean_absolute_error: 366910.7188
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 161968.4219 - mean_absolute_error: 161968.4219 - val_loss: 362263.1875 - val_mean_absolute_error: 362263.1875
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 164092.7656 - mean_absolute_error: 164092.7656 - val_loss: 363418.1875 - val_mean_absolute_error: 363418.1875
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 162777.9375 - mean_absolute_error: 162777.9375 - val_loss: 364164.0938 - val_mean_absolute_error: 364164.0938
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 146053.2500 - mean_absolute_error: 146053.2500 - val_loss: 363796.3750 - val_mean_absolute_error: 363796.3750
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 148756.2500 - mean_absolute_error: 148756.2500 - val_loss: 366230.3125 - val_mean_absolute_error: 366230.3125
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 161492.5469 - mean_absolute_error: 161492.5469 - val_loss: 367826.8438 - val_mean_absolute_error: 367826.8438
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 156110.5625 - mean_absolute_error: 156110.5625 - val_loss: 364160.3125 - val_mean_absolute_error: 364160.3125
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 151731.8125 - mean_absolute_error: 151731.8125 - val_loss: 364262.4688 - val_mean_absolute_error: 364262.4688
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 168937.6250 - mean_absolute_error: 168937.6250 - val_loss: 366911.1562 - val_mean_absolute_error: 366911.1562
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 155983.5156 - mean_absolute_error: 155983.5156 - val_loss: 366982.1875 - val_mean_absolute_error: 366982.1875
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 146516.4531 - mean_absolute_error: 146516.4531 - val_loss: 364634.2812 - val_mean_absolute_error: 364634.2812
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 163169.5156 - mean_absolute_error: 163169.5156 - val_loss: 368079.4062 - val_mean_absolute_error: 368079.4062
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 153384.3281 - mean_absolute_error: 153384.3281 - val_loss: 365594.3750 - val_mean_absolute_error: 365594.3750
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 152205.4844 - mean_absolute_error: 152205.4844 - val_loss: 366524.1250 - val_mean_absolute_error: 366524.1250
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 151424.8125 - mean_absolute_error: 151424.8125 - val_loss: 367935.7812 - val_mean_absolute_error: 367935.7812
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 148759.0625 - mean_absolute_error: 148759.0625 - val_loss: 365287.1875 - val_mean_absolute_error: 365287.1875
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 165424.4219 - mean_absolute_error: 165424.4219 - val_loss: 365119.4062 - val_mean_absolute_error: 365119.4062
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 161072.0938 - mean_absolute_error: 161072.0938 - val_loss: 368112.8750 - val_mean_absolute_error: 368112.8750
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 146786.5000 - mean_absolute_error: 146786.5000 - val_loss: 364205.9688 - val_mean_absolute_error: 364205.9688
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 153592.7344 - mean_absolute_error: 153592.7344 - val_loss: 363956.3750 - val_mean_absolute_error: 363956.3750
# Time taken to train neural network model: 71.90710186958313 seconds
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
show(ebm_global)

# %%
pred = model.predict(X_test)

print('MAE', metrics.mean_absolute_error(y_test, pred))
print('R2 Score', metrics.r2_score(y_test, pred))

# %%
show(ebm.explain_local(X_test[5:], y_test[5:]), 0)

# %%
# Test for prediction
target_property = {
    'type' : ['Apartment'],
    'room_num' : [2.5],
    'floor' : ["2"],
    'area_m2' : [80],
    'floors_num' : [1],
    'year_built' : [1990],
    'last_refurbishment' : [2002],
    'zip_code' : ["8004"],
    'city' : ["Zürich"],
    'canton' : ["Kanton Zürich"],
}

to_predict = pd.DataFrame(target_property)

# %%
to_predict = preprocessor.transform(to_predict)
pred = model.predict(to_predict)
print(f"The value of the property using the trained machine learning algorithm is of {pred[0]} CHF")
